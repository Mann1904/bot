# %%
import pandas as pd

# %%
df = pd.read_csv("/home/khyati/Desktop/hackathon_part2/temp_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                             0                             1  \
# 0           0  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 1           1  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 2           2  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744
# 3           3  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 4           4  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744
#
#                            2
# 0  <ss type="hi">(wave)</ss>
# 1                     hi sir
# 2                   Hi&apos;
# 3                       sir
# 4                     Hello

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#                               0                             1  \
# 0  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 1  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 2  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744
# 3  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085
# 4  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744
#
#                            2
# 0  <ss type="hi">(wave)</ss>
# 1                     hi sir
# 2                   Hi&apos;
# 3                       sir
# 4                     Hello

# %%
# !pip install html2text

# %%
import html2text
h = html2text.HTML2Text()

# %%
count = 0
for c, i in enumerate(df["2"]):
    try:
        if "<" in i or "</" in i:
            print(c,"-----")
            print(i)
            print("Text : ",h.handle(i))
            df["2"][c] = h.handle(i).replace("\n","").strip()
            count += 1
    except:
        print(i)
        pass
# Out:
# 0 -----
# <ss type="hi">(wave)</ss>
# Text :  (wave)
#
#
# 27 -----
# <partlist type="missed" alt="" callId="4645ac51-15f0-418d-b8ec-1a12b50e9186"><part identity="live:.cid.2ce9f8dccf1fc085"><name>live:.cid.2ce9f8dccf1fc085</name><duration>33.647</duration></part><part identity="live:.cid.4933a22bf564744"><name>support@ineuron.ai</name><duration>33.647</duration></part></partlist>
# Text :  live:.cid.2ce9f8dccf1fc08533.647support@ineuron.ai33.647
#
#
# 28 -----
# <partlist type="missed" alt="" callId="4645ac51-15f0-418d-b8ec-1a12b50e9186"><part identity="live:.cid.2ce9f8dccf1fc085"><name>live:.cid.2ce9f8dccf1fc085</name><duration>33.647</duration></part><part identity="live:.cid.4933a22bf564744"><name>support@ineuron.ai</name><duration>33.647</duration></part></partlist>
# Text :  live:.cid.2ce9f8dccf1fc08533.647support@ineuron.ai33.647
#
#
# 36 -----
# <a href="https://zoom.us/j/96193473094">https://zoom.us/j/96193473094</a>
# Text :  https://zoom.us/j/96193473094
#
#
# nan
# nan
# ...

# %%
count = 0
for c, i in enumerate(df["2"]):
    try:
        if "<" in i or "</" in i:
            print("-----")
            print(i)
            #print("Text : ",h.handle(i))
            #df[2][c] = h.handle(i)
            count += 1
    except:
        print(i)
        pass
# Out:
# -----
# <ss type="hi">(wave)</ss>
# -----
# <partlist type="missed" alt="" callId="4645ac51-15f0-418d-b8ec-1a12b50e9186"><part identity="live:.cid.2ce9f8dccf1fc085"><name>live:.cid.2ce9f8dccf1fc085</name><duration>33.647</duration></part><part identity="live:.cid.4933a22bf564744"><name>support@ineuron.ai</name><duration>33.647</duration></part></partlist>
# -----
# <partlist type="missed" alt="" callId="4645ac51-15f0-418d-b8ec-1a12b50e9186"><part identity="live:.cid.2ce9f8dccf1fc085"><name>live:.cid.2ce9f8dccf1fc085</name><duration>33.647</duration></part><part identity="live:.cid.4933a22bf564744"><name>support@ineuron.ai</name><duration>33.647</duration></part></partlist>
# -----
# <a href="https://zoom.us/j/96193473094">https://zoom.us/j/96193473094</a>
# nan
# nan
# nan
# nan
# -----
# ...

# %%
df.head()
# Out:
#                               0                             1           2
# 0  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085  (wave)\n\n
# 1  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085      hi sir
# 2  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744    Hi&apos;
# 3  8:live:.cid.2ce9f8dccf1fc085  8:live:.cid.2ce9f8dccf1fc085        sir
# 4  8:live:.cid.2ce9f8dccf1fc085   8:live:.cid.4933a22bf564744      Hello
